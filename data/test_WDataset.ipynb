# %%
import xarray as xr
import numpy as np
import h5py
from SlidingWindowDs import SlidingWindowDs

# %%
# --- Load your HDF5 into xarray ---
h5_path = "twoCA.h5"

with h5py.File(h5_path, "r") as f:
    print("Keys in HDF5 file:", list(f.keys()))
    dset = f["wca_exp_03"][:]  # loads into memory (OK for quick test)
    lat = np.arange(dset.shape[1])
    lon = np.arange(dset.shape[2])
    time = np.arange(dset.shape[0])
# Out:
# Keys in HDF5 file: ['wca_exp_03']

# %%
da = xr.DataArray(
    dset,
    dims=("time", "lat", "lon"),
    coords={"lat": lat, "lon": lon, "time": time}
)

# %%
# Make sure order is (time, lat, lon, feature)
da = da.transpose("time", "lat", "lon").expand_dims("feature")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Make sure order is (time, lat, lon, feature)
# ----> 2 da = da.transpose("time", "lat", "lon").expand_dims("feature")
#
# File ~/.cache/pypoetry/virtualenvs/fvg-adriatic-data-4MAnJKck-py3.11/lib/python3.11/site-packages/xarray/util/deprecation_helpers.py:143, in deprecate_dims.<locals>.wrapper(*args, **kwargs)
#     135     emit_user_level_warning(
#     136         f"The `{old_name}` argument has been renamed to `dim`, and will be removed "
#     137         "in the future. This renaming is taking place throughout xarray over the "
#    (...)
#     140         PendingDeprecationWarning,
#     141     )
#     142     kwargs["dim"] = kwargs.pop(old_name)
# --> 143 return func(*args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/fvg-adriatic-data-4MAnJKck-py3.11/lib/python3.11/site-packages/xarray/core/dataarray.py:3110, in DataArray.transpose(self, transpose_coords, missing_dims, *dim)
#    3077 """Return a new DataArray object with transposed dimensions.
#    3078
#    3079 Parameters
#    (...)
#    3107 Dataset.transpose
#    3108 """
#    3109 if dim:
# -> 3110     dim = tuple(infix_dims(dim, self.dims, missing_dims))
#    3111 variable = self.variable.transpose(*dim)
#    3112 if transpose_coords:
#
# File ~/.cache/pypoetry/virtualenvs/fvg-adriatic-data-4MAnJKck-py3.11/lib/python3.11/site-packages/xarray/namedarray/utils.py:173, in infix_dims(dims_supplied, dims_all, missing_dims)
#     171 existing_dims = drop_missing_dims(dims_supplied, dims_all, missing_dims)
#     172 if set(existing_dims) ^ set(dims_all):
# --> 173     raise ValueError(
#     174         f"{dims_supplied} must be a permuted list of {dims_all}, unless `...` is included"
#     175     )
#     176 yield from existing_dims
#
# ValueError: ('time', 'lat', 'lon') must be a permuted list of ('feature', 'time', 'lat', 'lon'), unless `...` is included

# %%
# --- Create dataset ---
seq_length = 8
ds = SlidingWindowDs(da, seq_length=seq_length)
print(ds)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 # --- Create dataset ---
#       2 seq_length = 8
# ----> 3 ds = SlidingWindowDs(da, seq_length=seq_length)
#       4 print(ds)
#
# File ~/workspace/studies/phd/projects/fvg_adriatic_data/src/fvg_adriatic_data/CA_RNN/data/SlidingWindowDs.py:21, in SlidingWindowDs.__init__(self, xr_data, seq_length)
#      19 # Extract dimensions
#      20 self.T = self.data.sizes["time"]
# ---> 21 self.H = self.data.sizes["latitude"]
#      22 self.W = self.data.sizes["longitude"]
#
# File ~/.cache/pypoetry/virtualenvs/fvg-adriatic-data-4MAnJKck-py3.11/lib/python3.11/site-packages/xarray/core/utils.py:452, in Frozen.__getitem__(self, key)
#     451 def __getitem__(self, key: K) -> V:
# --> 452     return self.mapping[key]
#
# KeyError: 'latitude'

# %%
# --- Test first valid sample ---
print(len(ds), "samples in dataset")
nb_invalid = 0
for i in range(len(ds)):
    try:
        X, y = ds[i]
        #continue
        #print(f"Index {i} → X shape {X.shape}, Y shape {y.shape}")
        
    except IndexError:
        #print(f"Index {i} is invalid, trying next...")
        nb_invalid += 1
        continue
print(f"Total invalid indices encountered: {nb_invalid}")
# Out:
# 105000 samples in dataset
# Total invalid indices encountered: 8232
